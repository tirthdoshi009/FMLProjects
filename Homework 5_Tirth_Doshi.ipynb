# %% [markdown]
# # Homework 5 - Neural Networks
#
# This is an individual assignment.
#
# **Due: Tuesday, April 14 @ 11:59 PM**
#
# ## Grading Rubric
#
# 1. **Problem 1 (50 pts):** you have completed all calculations and showed your work. You can upload a PDF scan of your handwritten calculations.
#
# 2. **Problem 2 (50 pts):** you have answered all questions and included the appropriate discussion.
#
# **Total: 100 pts**

# %% [markdown]
# # Multi-Layer Perceptrons and Backpropagation
#
# In this assignment, you will explore multi-layer perceptrons, backpropagation and parameter tuning. You have been given a data set that you will need for one of the problems (**UF_network.npy**) - make sure you download it.

# %% [markdown]
# # Problem 1 - Backpropagation
#
# Consider the following network: 1 input layer, 1 hidden layer and 1 output layer, each layer with 2 neurons.
#
# <div><img src="network.png", width="700"><!div>
#
# All weights are initialized to the values shown (and there are no biases for simplicity). Consider the data point $x=[1,1]^T$ with desired output vector $d=[1,0]^T$. Complete one iteration of backpropagation by hand assuming a learning rate of $\eta=0.1$.
#
# What would all the weight values be after one backpropagation iteration? Show your work.
#
# Use the sigmoid activation function: $\phi(x) = \frac{1}{1 + e^{-x}}$. Note that $\frac{d\phi(x)}{dx}=\phi'(x) = \phi(x)(1-\phi(x))$.

# %% [markdown]
# # Problem 2 - Learning Strategies
#
# In this problem, you will be working with the data set "UF Network" shown below (make sure you download the file **"UF_network.npy"**):

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import ListedColormap

UF_network = np.load('UF_network.npy')
X = UF_network[:,:2]
y = UF_network[:,2]

cm = ListedColormap(['blue', 'orange'])
plt.scatter(X[:,0],X[:,1],c=y, cmap=cm);
plt.xlabel('Feature 1')
plt.ylabel('Feature 2');

# %% [markdown]
# The following function will be helpful for plotting the decision boundary of your trained model.

# %%
def plot_LC_and_DB(X, model):
    '''This function will plot the learning curve and decision boundary
    for a given trained model and training data X.
    model: is a sklearn model structure
    X: training data'''
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.02),
                             np.arange(y_min, y_max, 0.02))
    
    fig = plt.figure(figsize=(15,5))
    fig.add_subplot(1,2,1)
    plt.plot(model.loss_curve_)
    plt.title('Learning Curve')
    plt.xlabel('Epochs')
    plt.ylabel('Loss Function')

    cm = ListedColormap(['blue', 'orange'])
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape) 
    fig.add_subplot(1,2,2)
    plt.contourf(xx, yy, Z, cmap=cm, alpha=.8);
    plt.title('Decision Boundary')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show();

# %% [markdown]
# For this problem, you will need to create a 2-hidden layer network to distinguish the letters and the background. Starter code is provided for you in the below code cell; it is using the ```scikit-learn``` library. You will need to determine:
#
# (1) the number of units for each hidden layer,
# (2) the learning rate, and
# (3) number of epochs.
#
# Answer the following questions:
#
# 1. How many units will you need in the first and second hidden layers? Why? Justify your answer by providing an explanation of each hidden unit role in creating the UF network.
#
# 2. Can you achieve the same goal with a *single hidden layer network*? Why or why not?
#
# 3. Using the starter code below, select three different learning rates and number of epochs. Report the results on the values selected. Generate the (a) learning curve and (b) decision boundary for the top three combinations of the different learning rates and number of epochs (total of 6 figures).
#
# 4. For the best learning rate and number epochs from the above plots, provide discussion on the (a) influence of each hyperparameter on training performance and (b) why the selected values worked well.

# %%
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier

# Do not change these parameters
net = MLPClassifier(activation='tanh',
                    n_iter_no_change = 1000)

# %%
# Create a list with your own set of values for all of these parameters
net_hidden_layers = [(16,6)]
net_learning_rate = [0.1]
epochs = [5,10,15,17,19,21,23,25,27,29,31,33,35,37,39,41,43,45,47,49,51,53,55,57,59,61,63,65,67,69,71,73,75,77,79,81,83,85,87,89,91,93,95,97,99]

for i in net_hidden_layers:
    print(i)
    for j in net_learning_rate:
        for k in epochs:
            net.set_params(hidden_layer_sizes = i, learning_rate_init = j, max_iter = k)
            net.fit(X, y)
            y_pred = net.predict(X)

            acc_score = accuracy_score(y, y_pred)
            print('-----------------------------------')
            print('Hidden Layer Architecture: ', i)
            print('Learning Rate: ', j)
            print('Number of Epochs: ', k)
            print('Accuracy = ', np.round(acc_score*100,2),'%')
            print('-----------------------------------')
            plot_LC_and_DB(X, net)
# Out:
# (16, 6)
# -----------------------------------
# Hidden Layer Architecture:  (16, 6)
# Learning Rate:  0.1
# Number of Epochs:  5
# Accuracy =  88.1 %
# -----------------------------------
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (5) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  (16, 6)
# Learning Rate:  0.1
# Number of Epochs:  10
# Accuracy =  84.8 %
# -----------------------------------
# ...

# %%
# Create a list with your own set of values for all of these parameters
net_hidden_layers = [(16,6)]
net_learning_rate = [0.1]
epochs = [5,10,15,17,19,21,23,25,27,29,31,33,35,37,39,41,43,45,47,49,51,53,55,57,59,61,63,65,67,69,71,73,75,77,79,81]

for i in net_hidden_layers:
    print(i)
    for j in net_learning_rate:
        for k in epochs:
            net.set_params(hidden_layer_sizes = i, learning_rate_init = j, max_iter = k)
            net.fit(X, y)
            y_pred = net.predict(X)

            acc_score = accuracy_score(y, y_pred)
            print('-----------------------------------')
            print('Hidden Layer Architecture: ', i)
            print('Learning Rate: ', j)
            print('Number of Epochs: ', k)
            print('Accuracy = ', np.round(acc_score*100,2),'%')
            print('-----------------------------------')
            plot_LC_and_DB(X, net)
# Out:
# (16, 6)
# -----------------------------------
# Hidden Layer Architecture:  (16, 6)
# Learning Rate:  0.1
# Number of Epochs:  5
# Accuracy =  88.2 %
# -----------------------------------
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (5) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  (16, 6)
# Learning Rate:  0.1
# Number of Epochs:  10
# Accuracy =  88.3 %
# -----------------------------------
# ...

# %% [markdown]
# ## Question 1: Number of units needed in first and second layer? Justify by providing an explaination of each hidden unit role:
#
# Number of units in the first layer : 16,
# Number of units in the second layer: 6
#
# 1. First Layer: We know that the first hidden layer corresponds to the number of lines. Observe that here U has 7 lines assuming that the top left horizontal line and the top right horizontal line of U are in the same level. Similarly, we observe that there are 9 lines in F. Thus in total we have 16 lines. Thus the first layer has 16 units and these units represent the decision boundaries.
# 2. Second Layer: Observe that both U and F are non-convex shapes. Thus we need to break U and F into its convex parts. So, we say U is broken into three parts, the top left vertical rectangle, the top right vertical rectangle and the bottom horizontal rectangle all of them are convex parts each corresponding to one unit. Similarly, we break F into 3 convex parts, the top horizontal rectangle,the left vertical rectangle and the middle horizontal rectangle. These correspond to the units of the second layer. Hence, in all we have 6 units in the second hidden layer.

# %%
# Create a list with your own set of values for all of these parameters
net_hidden_layers = [25]
net_learning_rate = [0.1]
epochs = [5,10,15,17,19,21,23,25,27,29,31,33,35,37,39,41,43,45,47,49,51,53,55,57,59,61,63,65,67,69,71,73,75,77,79,81,83,100]

for i in net_hidden_layers:
    print(i)
    for j in net_learning_rate:
        max_accuracy = 0
        for k in epochs:
            net.set_params(hidden_layer_sizes = i, learning_rate_init = j, max_iter = k)
            net.fit(X, y)
            y_pred = net.predict(X)
            acc_score = accuracy_score(y, y_pred)
            print('-----------------------------------')
            print('Hidden Layer Architecture: ', i)
            print('Learning Rate: ', j)
            print('Number of Epochs: ', k)
            print('Accuracy = ', np.round(acc_score*100,2),'%')
            print('-----------------------------------')
            plot_LC_and_DB(X, net)
# Out:
# 25
# -----------------------------------
# Hidden Layer Architecture:  25
# Learning Rate:  0.1
# Number of Epochs:  5
# Accuracy =  79.03 %
# -----------------------------------
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (5) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  25
# Learning Rate:  0.1
# Number of Epochs:  10
# Accuracy =  87.5 %
# -----------------------------------
# ...

# %% [markdown]
# ## Question 2: Can you achieve the same goal with a single hidden layer network? Why or why not?
# Yes, one can achieve the same goal with a single hidden layer network. As one can observe from the above graphs that we used a single hidden layer with 25 neurons with a learning rate of 0.1. It can be observed from the graphs that each of we  that our accuracy is 97.33% when the number of epochs is 59 over here.
# ## Why?
# This is due to the Universal approximation theorem that states that we can approximate any arbitrarily continous function with a single hidden layer. However, it does not say the number of units in the hidden layer and the activation function

# %% [markdown]
# ## Question 3: Using the starter code below, select three different learning rates and number of epochs. Report the results on the values selected. Generate the (a) learning curve and (b) decision boundary for the top three combinations of the different learning rates and number of epochs (total of 6 figures).

# %% [markdown]
# From the code below we get the array of best_epoch corresponding to the learning rate different learing rate. The epoch with maximum accuracy corresponding a particular learning rate is taken and appended into the best_epoch array. Here we print all the 18 graphs(9 for learning rate and 9 for decision boundary)

# %%
net_hidden_layers = [(16,6)]
net_learning_rate = [0.001,0.1,0.3]
epochs = [80,90,100]

best_epoch = []
best_acc = []

for i in net_hidden_layers:
    for j in net_learning_rate:
        max_acc = 0
        for k in epochs:
            net.set_params(hidden_layer_sizes = i, learning_rate_init = j, max_iter = k)
            net.fit(X, y)
            y_pred = net.predict(X)
            acc_score = accuracy_score(y, y_pred)
            if acc_score>max_acc:
                max_acc = acc_score
                max_epoch = k
            print('-----------------------------------')
            print('Hidden Layer Architecture: ', i)
            print('Learning Rate: ', j)
            print('Number of Epochs: ', k)
            print('Accuracy = ', np.round(acc_score*100,2),'%')
            print('-----------------------------------')
            plot_LC_and_DB(X, net)
        best_epoch.append(max_epoch)
        best_acc.append(max_acc)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (80) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  (16, 6)
# Learning Rate:  0.001
# Number of Epochs:  80
# Accuracy =  82.83 %
# -----------------------------------
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (90) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  (16, 6)
# Learning Rate:  0.001
# Number of Epochs:  90
# Accuracy =  81.3 %
# -----------------------------------
# ...

# %% [markdown]
# ## Below is a code that generates the top 3 graphs corresponding to the best combination of learning rate parameter and number of epochs

# %%
for i in net_hidden_layers:
    for j in range(len(net_learning_rate)):
        max_acc = 0
        k = best_epoch[j]
        net.set_params(hidden_layer_sizes = i, learning_rate_init = net_learning_rate[j], max_iter = k)
        net.fit(X, y)
        y_pred = net.predict(X)
        acc_score = accuracy_score(y, y_pred)
        print('-----------------------------------')
        print('Hidden Layer Architecture: ', i)
        print('Learning Rate: ', net_learning_rate[j])
        print('Number of Epochs: ', k)
        print('Accuracy = ', np.round(acc_score*100,2),'%')
        print('-----------------------------------')
        plot_LC_and_DB(X, net)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  (16, 6)
# Learning Rate:  0.001
# Number of Epochs:  100
# Accuracy =  80.57 %
# -----------------------------------
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# -----------------------------------
# Hidden Layer Architecture:  (16, 6)
# Learning Rate:  0.1
# Number of Epochs:  100
# Accuracy =  97.37 %
# -----------------------------------
# ...

# %% [markdown]
# ## Question 4: For the best learning rate and number epochs from the above plots, provide discussion on the (a) influence of each hyperparameter on training performance and (b) why the selected values worked well

# %% [markdown]
# # Observe that our learning rate was 0.001,0.1 and 0.3. The number of epochs we tested each of these were 80,90 and 100.
# 1. Influence of learning rate: With a learning rate of 0.001 the best we could achieve was for 100 epochs. Even after 100 epochs the accuracy was still very less. Thus we conclude that with a very low learning rate it takes a long time for our model to converge. Next, consider when the learning rate was 0.1, the accuracy achieved was 97.37% and the number of epochs required to achieve this was 100. Thus, we say that a learning rate of 0.1 was ideal. Next, consider when the learning rate is 0.3. When the learning rate is 0.3, we can observe from the graph above that our learning curve is fluctuating too much and thus the best we could achieve using the 3 epochs above was just 90.07%. Thus, with a high learning rate, the model is not able to converge at the minimum.
# Thus we say that our learning rate should not be too high nor too low accoring to the discussion above.
# 2. Influence of number of epochs: As we can see the accuracy is generally increasing as the number of epochs are increasing. Although we do not see it to be always true, since there can be minor fluctuations while converging to a minimum.

# %% [markdown]
# ## b) Why does the selected values worked well?
# The best results achieved for these 3 learning rates i.e 0.001, 0.1 and 0.3 were at epochs 100,100,100 respectively. The reason these values worked well was simply due to the number of epochs. As we increased the number of epochs, the model started learning the parameters better. After each epoch, our model became better and better. Although, note that this is not always true since there can be exceptions where our accuracy is fluctuating especially due to large learning rates.

# %% [markdown]
# ## Submit your Solution
#
# Create a PDF of the notebook with your solutions.
#
# Submit both your notebook and the PDF of your notebook to Homework 4 assignment page on Canvas.
#
# * For full credit consideration, make sure all output cells do not show any errors and all code is visible.
